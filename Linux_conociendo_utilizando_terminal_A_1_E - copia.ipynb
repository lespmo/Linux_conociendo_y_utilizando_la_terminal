# %% [markdown]
# <a href="https://colab.research.google.com/github/ahcamachod/2145-data-science-probando-relaciones-con-regresion-lineal/blob/proyecto-final/precios_de_inmuebles_regresion_lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# #🐧 <font color=#56B4E9 size=6>**Articulo: Empezando con la terminal: manejando archivos y carpetas**</font>
# ***

# %% [markdown]
# El articulo completo se encuentra en el siguiente enlace:
#
# [Empezando con la terminal: manejando archivos y carpetas | Alura Cursos Online](https://https://www.aluracursos.com/blog/empezando-con-la-terminal-manejando-archivos-y-carpetas)

# %% [markdown]
# ***
# #📝🖥️ <font color=#56B4E9 size=6>📝🖥️**Curso: Linux: conociendo y utilizando la terminal**</font>
# ***

# %% [markdown]
# ## 🗃️⚙️ <font color=green size=6> 🗃️⚙️ **5 EDICION DE ARCHIVOS CON VI - INSERCION, ACTUALIZACION, BORRADO Y REPETICION**</font>
# ***

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**5.1 Edición de archivos con vi**</font>
# ***

# %% [markdown]
# COMANDOS CON VI
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# YA ESTANDO EN vi
# CON LAS FLECHAS NAVEGO EN EL ARCHIO

# %% [markdown]
# ESTANDO EN NAVEGASION EN EL MODO VI
# PUEDO CION LA TECLA I = INSERTAR
# PUEDO CON LA TECLA A = ACTUALIZAR.
# SALGO CON LA TECLA ESC

# %% [markdown]
# PUEDO DIGITAR ": " PARA INSERTAR COMANDOS

# %% [markdown]
# COMADOS"W" = GRABAR

# %% [markdown]
# COMANDOS "Q " SALIR

# %% [markdown]
# LA TECLA "X" QUITA CARACTERES

# %% [markdown]
# EL NUMEROD DECARACTERES Y LUEGO LA TECLA "X" BORRA LO QUE DE ESA LONGITUD EN CARACTERES

# %% [markdown]
# PARA SALIR SIN GRABAR CAMBIO
# PRIMERO LA TRECLA":"
# LUEGO "q!"

# %% [markdown]
# BORRAR LINEAS COMPETAS "dd"

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**5.2 Salvando y saliendo**</font>
# ***

# %% [markdown]
# Cuál de las siguientes alternativas es el comando correcto que podemos usar en modo comando de vi para salvar las actualizaciones realizadas y salir.
#
#
# Alternativa CORRECTA
#
#
# ```
# # Tiene formato de código
#
# :wq
# ```
#
#
#
# Exacto. De esta forma le decimos a vi guarda y sal de la aplicación.

# %% [markdown]
# Alternativa incorreta
#
# ```
# # Tiene formato de código
#
#
# :q!
# ```
#
#
# Error. De esta forma salimos y explícitamente le decimos a vi que no queremos guardar los cambios.
#
# Alternativa incorreta
#
# ```
# # Tiene formato de código
#
#
# :w
#
# ```
#
# Casi. Con este comando sólo guardamos pero no salimos.
#
#
# Alternativa incorreta
#
# ```
# # Tiene formato de código
#
#
# :q
#
#
# ```
#
# Incorrecto. Este comando sólo indica que debemos salir.

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**5.3 Saliendo sin guardar**</font>
# ***

# %% [markdown]
# Cuál de las siguientes alternativas es el comando correcto que podemos usar en modo comando de vi para salir sin guardar las actualizaciones realizadas.
# ALTERNATIVA CORRECTA
#
# ```
# # Tiene formato de código
#
#
# :q!
#
# ```
#
# Exacto. Así le decimos a vi que salga de la aplicación e ignore los cambios.

# %% [markdown]
# Alternativa incorreta
#
# ```
# # Tiene formato de código
#
# :w
# ```
# Error. Estamos indicando que deseamos guardar con ese comando.
#
#
# Alternativa incorreta
#
# ```
# # Tiene formato de código
# :wq
# ```
#
# Incorrecto. De esta forma le decimos a vi guarda y sal de la aplicación.
#
#
# Alternativa incorreta
#
# ```
# # Tiene formato de código
# :q
# ```
#
# Casi. Este comando sólo indica que debemos salir. vi va dar un mensaje de que existen cambios y no estamos guardando.

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**5.4 Utilizando vi**</font>
# ***

# %% [markdown]
# Vamos a utilizar vi para abrir el archivo google.txt.
#
#
# ```
# # Tiene formato de código
# vi google.txtCopia el código
# ```
#
#
# En la segunda línea del archivo, inserte el siguiente texto:
#
#
#
# ```
# # Tiene formato de código
# De wikipedia, De wikipedia, la enciclopedia abierta
# ```
#
#
# Copia el código
# Borre el texto “De wikipedia,”. Realice esto con un único comando.
#
# Al final, borre la línea que acabas de insertar, guarde los cambios y salga del editor.

# %% [markdown]
# Para insertar el texto, podemos navegar hasta el inicio de la segunda línea y digita i, de esta forma entramos en el modo de inserción y somos capaces de agregar texto en el archivo. Digite el texto y pulse enter al final para pasar a la siguiente línea.
#
# Para borrar el texto “De wikipedia,”, necesitamos primero entrar en modo de comandos. Para ello apretamos la tecla Esc. Navegamos al inicio de la segunda línea y digitamos el número de caracteres que deseamos quitar, en este caso 14, luego presionamos la tecla x.
#
# Para borrar la línea completa, necesitamos navegar a la línea que deseamos borrar y usamos el comando dd en modo de comandos. Para guardar y salir del editor usamos :wq.

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**5.5 Navegando con vi**</font>
# ***

# %% [markdown]
# MOYERSE AL FINAL DEL ARCHIVO ESTANDO EN VI DEL ARCHIVO
# LA TECALA SHIFT+g

# %% [markdown]
# MOVERSE A PRIMERA LINEA "1g"

# %% [markdown]
# MOVERSE A ALGUNA LIEA NUMERO DE LA LINEA Y G "21G"

# %% [markdown]
# MOVERSE AL FINAL DE UNA ÑINEA "SHIFT + $"

# %% [markdown]
# MOVER AL INICIO DE UNA LINEA TECLA "0"

# %% [markdown]
# BUSCAR UNA PALABRA EN EL ARCHIVO TECLA "/" LUEGO LA PALABRA

# %% [markdown]
# PARA LA SIGUIENTE  PALABRA BUSCADA "N"

# %% [markdown]
# PARA LA ANTERIOR PALABRA BUSCADA "SHIFT + N"

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**5.6 Inicio y fin del archivo**</font>
# ***

# %% [markdown]
# Cuál de las siguientes alternativas es el comando correcto que debemos usar para ir hasta el final y al inicio del archivo.

# %% [markdown]
# ALTERNATIVA CORRECTA
#
# ```
# # Tiene formato de código
#
# G(Shift + g) y 1G (Shift +g)
# ```
#
#
#
# Correcto. Para llegar al final del archivo usamos el comando G (Shift + g) y para ir al inicio del archivo usamos el comando 1G (Shift + g).

# %% [markdown]
# Alternativa incorreta
#
#
# ```
# # Tiene formato de código
# gg y G (Shift + g)
# ```
#
#
#
# Casi. Sólo que está invertido. El comando gg va para el inicio y el G va para el final.
#
# Alternativa incorreta
#
# ```
# # Tiene formato de código
# :head y :tail
# ```
#
# Incorrecto. Esos comando no son válidos en vi.Alternativa incorreta
#
# ```
# # Tiene formato de código
# gg y 2g
# ```
#
# Errado. El gg va para el inicio y el 2g no es válido.

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**5.7 Inicio y fin de la línea**</font>
# ***

# %% [markdown]
# Cuál de las siguientes alternativas es el comando correcto que debemos usar para ir al inicio y al final de la línea.

# %% [markdown]
# .
#
# Alternativa CORRECTA
#
# ```
# # Tiene formato de código
# 0 y $
# ```
# Correcto. Para ir al inicio de la línea usamos el comando 0 y para ir al final de la línea usamos el comando $.

# %% [markdown]
# Alternativa incorreta
#
#
# ```
# # Tiene formato de código
# G(Shift + g) y gg
# ```
# Errado. El G va para fin de archivo. Y el comando gg para el inicio del archivo.
#
# Alternativa incorreta
#
# ```
# # Tiene formato de código
# $ y 0
# ```
# Casi. Sólo que está invertido. El comando 0 va para el inicio y el S va para el final.
#
# Alternativa incorreta
#
# ```
# # Tiene formato de código
# 0G (Shift + g) y $
# ```
# Incorrecto. El comando 0G va para el fin del archivo en general.

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**5.8 Buscando en el archivo**</font>
# ***

# %% [markdown]
# Vamos a usar vi para abrir el archivo google.txt:
#
#
# ```
# # Tiene formato de código
# vi google.txtCopia el código
# ```
# Use el comando que le permita navegar hasta la línea 30.
#
# Busque la palabra “Yahoo!”. Navega entre las apariciones del término, usando el comando que permite esta operación hasta recorrer todas las apariciones.

# %% [markdown]
# Opinión del instructor
#
# Si queremos navegar hasta la línea 30, usamos el comando 30G (Shift + g). Podemos también usar el comando 30gg.
#
# Para buscar el término “Yahoo!”, usamos el comando /Yahoo!. Para navegar hasta la siguiente ocurrencia o aparición del término usamos n. Utilizamos N(Shift + n) si queremos navegar para una ocurrencia o aparición anterior.

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**5.9  Copiar y pegar en vi**</font>
# ***

# %% [markdown]
# COPIAR EN VI
# UBICANDO EN LA LINEA "YY"

# %% [markdown]
# PEGAR CON LA TECLA "P" EN DONDE QUIERO PEGAR

# %% [markdown]
# PARA PEGAR VARIAS VECES LE INSDICO LA CANTIDAD DE LINEAS ANTES DE LA p
# EJEMPLO "3P"

# %% [markdown]
# COPIAR VARIAS LINEAS "3YY" COPIA TRES LINEAS

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**5.10  CopiaNDO**</font>
# ***

# %% [markdown]
# Cuál de las siguientes alternativas es el comando correcto que debemos usar en vi para copiar 6 líneas?
#
# Seleccione una alternativa

# %% [markdown]
# Alternativa correta
#
# ```
# # Tiene formato de código
# 6yy
# ```
#
# Correcto. Para copiar la línea donde está el cursor, usamos el comando yy y para copiar 6 líneas usamos 6yy.

# %% [markdown]
# Alternativa INcorreta
# ```
# # Tiene formato de código
#
# 6pp
# ```
# Error. El comando p es para pegar.
#
#
# Alternativa INcorreta
# ```
# # Tiene formato de código
# 6y
# ```
# Errado. El y sólo copia la línea actual.
#
# Alternativa INcorreta
# ```
# # Tiene formato de código
# 6c
# ```
# Incorrecto. El comando c no realiza ninguna copia.

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**5.11 pEGANDO**</font>
# ***

# %% [markdown]
# Cuál de las siguientes alternativas es el comando correcto que debemos usar en vi para pegar 2 veces el contenido copiado?

# %% [markdown]
# Alternativa correta
# ```
# # Tiene formato de código
#
# 2p
# ```
# Correcto. Para pegar el contenido copiado usamos el comando p . Para pegar 2 veces usamos 2p.

# %% [markdown]
# Alternativa INcorreta
# ```
# # Tiene formato de código
# 2yy
# ```
# Errado. El yy es para copiar.
#
#
# Alternativa correta
# ```
# # Tiene formato de código
# 2y
# ```
#
# Error. El comando y es para copiar la línea actual.
#
# Alternativa correta
#
# ```
# # Tiene formato de código
# 2pp
# ```
# Error. Sólo necesita una p en el comando.

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**5.12 pEGANDO**</font>
# ***

# %% [markdown]
# Vamos a usar vi para abrir el archivo google.txt:
#
# ```
# # Tiene formato de código
# vi google.txtCopia el código
# ```
# Copia las 3 primeras líneas del archivo. Salta para la línea 40 y pega 5 veces el contenido copiado anteriormente.

# %% [markdown]
# Opinión del instructor
#
# Para copiar las 3 primeras líneas usamos el comando 3yy. Para ir hasta la línea 40 podemos ejecutar el comando 40G (Shift + g). Al final, para pegar 5 veces el contenido copiado anteriormente usamos 5p.

# %% [markdown]
# ## cambiar
