# %% [markdown]
# <a href="https://colab.research.google.com/github/ahcamachod/2145-data-science-probando-relaciones-con-regresion-lineal/blob/proyecto-final/precios_de_inmuebles_regresion_lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# #🐧 <font color=#56B4E9 size=6>**Articulo: Empezando con la terminal: manejando archivos y carpetas**</font>
# ***

# %% [markdown]
# El articulo completo se encuentra en el siguiente enlace:
#
# [Empezando con la terminal: manejando archivos y carpetas | Alura Cursos Online](https://https://www.aluracursos.com/blog/empezando-con-la-terminal-manejando-archivos-y-carpetas)

# %% [markdown]
# ***
# #📝🖥️ <font color=#56B4E9 size=6>📝🖥️**Curso: Linux: conociendo y utilizando la terminal**</font>
# ***

# %% [markdown]
# ## 📂 <font color=green size=6> 📂 **1 TRABAJANDO CON ARCHIVOS Y DIRTECTORIOS**</font>
# ***

# %% [markdown]
# ### 📝<font color=green size=6>📝**1.2 Preparando el ambiente**</font>
# ***

# %% [markdown]
# Para comenzar nuestro curso... Por supuesto, necesitaremos un computador con Linux para usar.
# > Añadir blockquote
#
# > Añadir blockquote
#
# Hay varios tipos de Linux en el mercado. En las clases vamos a usar <a href='https://ubuntu.com/download/desktop'>Ubuntu</a>. Si no tiene Linux instalado, le recomendamos Ubuntu. Pero puedes usar cualquier otra versión.
#
# Si su sistema operativo principal no es Linux, le recomendamos que use una máquina virtual para instalar <a href='https://ubuntu.com/download/desktop'>Ubuntu</a> y la use dentro de su Windows o Mac. Una opción es instalar  <a href='https://www.oracle.com/es/virtualization/virtualbox/'>VirtualBox</a> o  <a href='https://www.vmware.com/'>VMWare</a> Player y luego instalar Ubuntu en él.
#
# También existe la opción de usar  <a href='https://gitforwindows.org/'>Git Bash</a>, una línea de comando para ejecutar el lenguaje Git que también ofrece una terminal Linux para la computadora.
#
# Una última opción posible es simplemente conectarse de forma remota vía SSH a una máquina Linux que tenga disponible.
#
# Podría ser un servidor remoto, otra máquina de la empresa o incluso usar algún servicio en la nube para cargar una nueva máquina.

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**1.3 Comandos de Archivos**</font>
# ***

# %% [markdown]
# PRimeros comandos
#
#
# <a href='https://ubuntu.com/download/desktop'>Ubuntu</a>.
#
# #### Comando `pwd` en Linux
#
# El comando `pwd` (print working directory) se utiliza para mostrar la ruta absoluta del directorio actual.
#
# ##### Ejemplo de uso
#
# ```bash
# pwd
# ```
#
# **Salida típica:**
# ```
# /home/usuario/proyecto
# ```

# %% [markdown]
# #### Comando `ls` en Linux
#
# El comando `ls` se utiliza para listar los archivos y carpetas dentro de un directorio.
#
# #### Ejemplo de uso
#
# ```bash
# ls
# ```
#
# **Salida típica:**
# ```
# Documentos  Descargas  Imágenes  Música
# ```
#
# #### Opciones comunes
#
# - `ls -l` : Lista con detalles (permisos, dueño, tamaño, fecha, etc.).
# - `ls -a` : Muestra archivos ocultos.
# - `ls -lh` : Lista detallada con tamaños legibles (K, M, G).
# - `ls -la` :

# %% [markdown]
# #### Comando `ls -la` en Linux
#
# El comando `ls -la` muestra una lista detallada de todos los archivos y carpetas en el directorio actual, incluyendo los archivos ocultos (los que comienzan con un punto `.`).
#
# #### Ejemplo de uso
#
# ```bash
# ls -la
# ```
#
# **Salida típica:**
# ```
# drwxr-xr-x  2 usuario usuario 4096 sep  4 22:30 .
# drwxr-xr-x 18 usuario usuario 4096 sep  4 22:00 ..
# -rw-r--r--  1 usuario usuario  220 sep  4 22:00 .bash_logout
# -rw-r--r--  1 usuario usuario 3771 sep  4 22:00 .bashrc
# drwxr-xr-x  2 usuario usuario 4096 sep  4 22:30 Documentos
# -rw-r--r--  1 usuario usuario    0 sep  4 22:30 archivo.txt
# ```
#
# **Significado de las columnas:**
#
# - Permisos
# - Número de enlaces
# - Propietario
# - Grupo
# - Tamaño (en bytes)
# - Fecha y hora de la última modificación
# - Nombre del archivo o carpeta

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Comando `echo` en Linux
#
# El comando `echo` se utiliza para mostrar una línea de texto o una variable por pantalla.
#
# #### Ejemplo de uso
#
# ```bash
# echo "Hola, mundo"
# ```
#
# **Salida:**
# ```
# Hola, mundo
# ```
#
# ---
#
# #### Comando `cat` en Linux
#
# El comando `cat` se utiliza para mostrar el contenido de un archivo, concatenar archivos y redirigir su salida.
#
# #### Ejemplo de uso
#
# ```bash
# cat archivo.txt
# ```
#
# **Salida típica:**
# ```
# Este es el contenido de archivo.txt
# ```
#
# #### Otras formas de usar `cat`:
#
# - Mostrar varios archivos a la vez:
#
#   ```bash
#   cat archivo1.txt archivo2.txt
#   ```
#
# - Crear un archivo nuevo (Ctrl+D para terminar):
#
#   ```bash
#   cat > nuevoarchivo.txt
#   ```
#
# - Añadir contenido a un archivo existente:
#
#   ```bash
#   cat >> archivo.txt
#   ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Comando `man` en Linux
#
# El comando `man` (manual) se utiliza para consultar el manual de ayuda de otros comandos de Linux. Proporciona información detallada sobre cómo usar un comando, sus opciones y ejemplos.
#
# #### Ejemplo de uso
#
# ```bash
# man ls
# ```
#
# Esto mostrará la página de manual para el comando `ls`.
#
# #### Ejemplo de salida
#
# ```
# LS(1)                     Manual de usuario de Linux                    LS(1)
#
# NOMBRE
#        ls - listar el contenido de un directorio
#
# SINOPSIS
#        ls [OPCIÓN]... [ARCHIVO]...
#
# DESCRIPCIÓN
#        Lista información sobre los ARCHIVOS (por defecto, los archivos en el directorio actual).
# ...
# ```
#
# #### Salir del manual
#
# Para salir de la página del manual y volver a la terminal, presiona la tecla `q`.
#
# #### Otros ejemplos útiles
#
# - Ver el manual de `cat`:
#   ```bash
#   man cat
#   ```
#
# - Buscar una palabra dentro del manual (cuando estás dentro del manual, escribe `/palabra` y presiona Enter).
#
# ---

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**1.4 El comando pwd**</font>

# %% [markdown]
# ¿Para qué usamos el comando pwd?
#
#
# Alternativa incorreta
# Para saber en qué directorio estamos actualmente.
#
#
# ¡Correcto! En mi caso estoy en el directorio base de mi usuario: /home/leonardo.

# %% [markdown]
# Para crear un nuevo archivo.
#
#
# Incorrecto. El comando pwd no cambia nada en el sistema de archivos.
#
# Alternativa incorreta
# Para apagar el computador.
#
#
# No. Para ello se usa el comando poweroff.
#
# Alternativa incorreta
# Para cambiar de directorio actual.
#
#
# Error. Para cambiar de directorio actual se usa el comando cd.

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**1.5  El comando whoami**</font>

# %% [markdown]
# Ejecuta el comando whoami en la terminal. ¿Qué hace este comando? ¿Qué se muestra en la pantalla?
#
# Alternativa incorreta
# El nombre del usuario en Linux.
#
#
# ¡Correcto!. El comando whoami muestra el nombre del usuario actual. En mi caso el usuario es leonardo por lo que salida es:
#
#
# ```bash
# # Tiene formato de código
# $ whoami
# leonardo
# ```
#
#
# $ whoami
# leonardo

# %% [markdown]
# El directorio actual del usuario.
#
# Incorrecto.
#
# El comando pwd muestra el directorio actual del usuario.
#
# Alternativa incorreta
# Muestra la lista de archivos del directorio actual.
#
# ¡Error! Para mostrar la lista de archivos se usa el comando ls.
#
# Alternativa incorreta
# root, el usuario raíz.
#
# No. El usuario actual no es root.

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**1.6 Listado de archivos**</font>

# %% [markdown]
# No solo es importante saber el nombre del directorio donde estamos posicionados. Es importante conocer el contenido del directorio actual. Es decir, saber qué archivos están contenidos en él. ¿Cómo podemos consultar la lista de archivos que están dentro del directorio actual?

# %% [markdown]
# ls
#
# ¡Exacto! El comando ls muestra la lista de archivos contenidos en el directorio actual. En Ubuntu, la terminal nos ayuda coloreando de diferente forma los archivos y los directorios.

# %% [markdown]
# echo
#
# No, echo muestra un mensaje en pantalla.

# %% [markdown]
# cat
#
# ¡Error! El comando cat nos muestra el contenido de un archivo en particular.
#
# Alternativa incorreta
#
#
# clear
#
# Incorrecto. Este comando limpia el contenido de la terminal.
#
# Alternativa incorreta
#
#
# pwd
#
# Incorrecto. El comando pwd muestra el directorio actual del usuario.

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**1.7 ls con parámetros**</font>

# %% [markdown]
# -a
#
# Correcto. Para mostrar los archivos y directorios incluyendo archivos ocultos pasamos el parámetro -a para el comando ls.

# %% [markdown]
# -l
#
# Sí. Para mostrar los detalles usamos el comando -l.

# %% [markdown]
# man
#
# Incorrecto.

# %% [markdown]
# -j
#
# Error. No es una opción válida para ese comando.
#
# Para mostrar del directorio actual, los archivos y directorios utilizamos el comando ls.
#
#
# ```linux
# # Tiene formato de código
# $ ls
# bienvenido.txt
#
# ```
# El resultado del comando ls puede variar de acuerdo a su distribución linux. Esto es normal.
#
#
# ```
# # Tiene formato de código
#
#
#
#
# $ ls -la
# total 36
# drwxr-xr-x 4 vagrant vagrant 4096 Jan 13 19:00 .
# drwxr-xr-x 4 root    root    4096 Jan  6 12:19 ..
# -rw------- 1 vagrant vagrant  184 Jan  6 13:29 .bash_history
# -rw-r--r-- 1 vagrant vagrant  220 Apr  9  2014 .bash_logout
# -rw-r--r-- 1 vagrant vagrant 3637 Apr  9  2014 .bashrc
# drwx------ 2 vagrant vagrant 4096 Jan  6 12:19 .cache
# -rw-rw-r-- 1 vagrant vagrant    0 Jan  6 13:06 .cloud-locale-test.skip
# -rw-r--r-- 1 vagrant vagrant  675 Apr  9  2014 .profile
# drwx------ 2 vagrant vagrant 4096 Jan  6 12:19 .ssh
# -rw-rw-r-- 1 vagrant vagrant   37 Jan 13 19:00 bienvenido.txt
# ```

# %% [markdown]
# echo
#
# No, echo muestra un mensaje en pantalla.

# %% [markdown]
# >
#
# Incorrecto. Al colocar > en una instrucción, indicas que vas a guardar el resultado en un archivo o algún dispositivo disponible.

# %% [markdown]
# ### 🛠️📦💻<font color=green size=6>🛠️📦💻**1.8 Manipulando archivos**</font>

# %% [markdown]
# 1 - Utiliza el comando adecuado para mostrar, en el terminal, el mensaje "Bienvenido al curso de Linux de Alura".
#
# 2 - Ahora escribe el mensaje de arriba en un archivo llamado bienvenido.txt, usando el comando que realiza esta tarea.
#
# Aproveche la oportunidad para verificar si el archivo fue creado usando el comando ls.
#
# Sugerencia: Recuerde que podemos navegar entre los comandos ya escritos usando las teclas de flecha hacia arriba y hacia abajo.

# %% [markdown]
# Opinión del instructor
#
# Para mostrar el mensaje "Bienvenido al curso de Linux de Alura" en la terminal, usamos el comando echo:

# %% [markdown]
# ```
# # Tiene formato de código
# $ echo "Bienvenido al curso de Linux de Alura"
# ```
# Para redirigir la salida del comando echo al archivo bienvenido.txt:
# ```
# # Tiene formato de código
# $ echo "Bienvenido al curso de Linux de Alura" > bienvenido.txt
# ```
# Podemos verificar si el archivo fue creado usando el comando ls:
# ```
# # Tiene formato de código
# $ ls
# bienvenido.txt
# ```

# %% [markdown]
# Practica en la maquina virtual de UBUNTU bajo VIRTUAL_BOX
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  ### 🛠️📦💻<font color=green size=6>🛠️📦💻**1.9 Mostrando el contenido de un archivo**</font>

# %% [markdown]
# Cuál es el comando que necesitamos usar para mostrar el contenido del archivo bienvenido.txt en la pantalla?
#
# Seleccione una alternativa

# %% [markdown]
# ¡Enhorabuena, has acertado!
# Alternativa correta
#
#
# ```
# # Tiene formato de código
# cat bienvenido.txt
# ```
#
#
#
#
# Correcto. El comando cat recibe como parámetro el nombre del archivo y presenta su contenido en la pantalla del terminal.

# %% [markdown]
# Alternativa incorreta
#
#
# ```
# # Tiene formato de código
# println bienvenido.txt
# ```
#
#
#
#
# Error. El comando println existe en ciertos lenguajes de programación pero no es un comando válido del terminal de linux.
#
# Alternativa incorreta
#
#
# ```
# # Tiene formato de código
# echo bienvenido.txt
# ```
#
#
#
#
# Incorrecto. Esto mostrará el texto “bienvenido.txt” en la pantalla.
#
# Alternativa incorreta
#
#
# ```
# # Tiene formato de código
# puts bienvenido.txt
# ```
#
#
#
#
# No, este comando es común en ciertos lenguajes de programación pero no es parte de los comando del terminal de linux.

# %% [markdown]
#  ### 🛠️📦💻<font color=green size=6>🛠️📦💻**1.10 Limpiando la pantalla**</font>

# %% [markdown]
# En algunos momentos terminamos con la terminal llena de comandos y de sus resultados. ¿Cuál comando podemos utilizar para limpiar la pantalla del terminal?
#
# Alternativa incorreta
#
# ```
# # Tiene formato de código
#
#
# erase
# ```
#
#
# Error. En linux no existe el comando erase.
#
#
# Alternativa incorreta
#
# ```
# # Tiene formato de código
#
# clean
# ```
#
#
#
# Incorrecto. Este comando no existe en linux.
#
# Alternativa incorreta
#
#
# ```
# # Tiene formato de código
#
# cls
# ```
#
#
#
# No. Este comando es válido en el sistema operativo DOS o en terminales basadas en el sistema operativo Windows.

# %% [markdown]
# Alternativa correta
#
#
# ```
# # Tiene formato de código
#
# clear
# ```
#
#
#
# Correcto. Utilizamos el comando clear para limpiar la pantalla del terminal. El atajo Ctrl + L ejecuta la misma función.

# %% [markdown]
#  ### 🛠️📦💻<font color=green size=6>🛠️📦💻**1.11 Manual de comando**</font>

# %% [markdown]
# Muchos de los comandos que usted verá en este curso tienen varias opciones o parámetros que alteran el comportamiento del comando. Para saber las posibles opciones de un comando y cada una de las opciones disponibles, puedes verificar el manual del comando. Esto es posible digitando el comando man seguido del nombre del comando a consultar.
#
# Verificar el manual del comando cat y selecciona la opción que debe ser usada para además de mostrar el contenido, sea mostrado el número de cada línea.

# %% [markdown]
# Alternativa incorreta
# ```
# # Tiene formato de código
# car -v
# ```
# No. La opción -v muestra los caracteres ocultos o especiales. Ex: Tabulaciones, saltos de línea, etc.
#
# Alternativa incorreta
# ```
# # Tiene formato de código
# cat -l
# ```
#
# Esta opción no está disponible en el comando cat.
#
# ¡Enhorabuena, has acertado!
# Alternativa Correta
# ```
# # Tiene formato de código
# cat -n
# ```
# Correcto. La opción -n muestra las líneas además de mostrar el contenido del archivo.
#
# Alternativa incorreta
# ```
# # Tiene formato de código
# cat -a
# ```
# Esta opción no existe en el comando cat.
